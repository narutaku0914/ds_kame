# %% [markdown]
# 第33回 Pythonスクリプトを作ってJupyterから呼び出す

# %% [markdown]
# Jupyterはあくまでも実行環境であり，関数やクラスを定義する場所ではない
# → 基本的には本記事で紹介するように，Pythonのスクリプトを別途作成し，関数やクラスをそこにまとめよう

# %%
import util

util
# Out:
# <module 'util' from '/work/util.py'>

# %%
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

im = cv2.imread('lenna.png')
plt.imshow(im)

# %%
crop_im = util.crop_img(im)
plt.imshow(crop_im)

# %% [markdown]
# 実際の開発では画像がcrop_sizeより小さい場合のエラーハンドリングが必要
# 今回はただのサンプルコードなのでそこまでは

# %%
# スクリプトの更新を随時Jupyterで読み込む
# おまじない
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Jupyterには定義せずに都度スクリプトファイルを作ってそこに定義
